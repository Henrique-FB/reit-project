# %%
import pandas
from bs4 import BeautifulSoup
import requests

from selenium import webdriver

# %%
URL = "https://fiis.com.br/abcp11/"
dr = webdriver.Chrome()
dr.get(URL)

# %%
page = requests.get(URL)
soup = BeautifulSoup(dr.page_source, "lxml")

# %%
print(soup.text)
# Out:
# ABCP11 - Grand Plaza Shopping - Fiis
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nossos sites utilizam cookies e outras tecnologias semelhantes para melhorar a sua experiência em nossas plataformas. Para obter mais informações sobre os cookies que usamos, leia nossa Política de Privacidade.
#
#
#
#     Aceitar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# menu mobile
#
# Notícias
# Artigos
# FiisFiis
#
# Atualizações
# Lista de Fiis
# Resumo
# Lupa de FIIs
# Rendimentos
# Assembleias
# Fundos do IFIX
# Glossário
#
#
# GratuitoGratuito
#
# Minicurso
# Checklist
# Declarar FIIs
# FIIs para novatos
# Whatsapp
#
#
# AproveiteAproveite
#
# Carteira Suno
# Funds Learning
# Investindo em Fiis
#
#
# WhatsApp
#
#
#
# BUSCAR POR FUNDO
#
# background modal
#
#
#
#
#
# Buscar por ticker ou empresa
#
#
#
# fechar modal
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Início  Lista de Fiis  ABCP11
#
#
# ABCP11
# Grand Plaza Shopping
#
# Seguir
#
# background modal fechar
#
#
#
# ...

# %%
test = soup.findAll('div', attrs={"class":"table__linha"})
test
# Out:
# [<div class="table__linha">
#  							Rendimento						</div>,
#  <div class="table__linha">
#  							31.10.2024						</div>,
#  <div class="table__linha">
#  							07.11.2024						</div>,
#  <div class="table__linha">
#  							R$ 77,00						</div>,
#  <div class="table__linha">
#  							0,91%						</div>,
#  <div class="table__linha">
#  							R$ 0,70						</div>,
#  <div class="table__linha">
#  							Rendimento						</div>,
#  <div class="table__linha">
#  							30.09.2024						</div>,
#  <div class="table__linha">
#  							07.10.2024						</div>,
#  <div class="table__linha">
#  							R$ 71,80						</div>,
#  <div class="table__linha">
#  							0,97%						</div>,
#  <div class="table__linha">
#  							R$ 0,70						</div>,
#  <div class="table__linha">
#  							Rendimento						</div>,
#  <div class="table__linha">
#  							30.08.2024						</div>,
#  <div class="table__linha">
#  							06.09.2024						</div>,
#  <div class="table__linha">
# ...
